# %%
from trust_2 import get_simrank
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
G = nx.Graph()

G.add_edge('x_send', 'x_1')
G.add_edge('x_send', 'x_2')
G.add_edge('x_send', 'x_3')
G.add_edge('x_send', 'x_4')

G.add_edge('x_recv', 'x_1')
G.add_edge('x_recv', 'x_2')
G.add_edge('x_recv', 'x_3')
G.add_edge('x_recv', 'x_4')

pos = {'x_send': [-1, 0],
       'x_recv': [1, 0],
       'x_1': [0, 1],
       'x_2': [0, 0.33],
       'x_3': [0, -0.33],
       'x_4': [0, -1],
      }

# %%
pos
# Out:
# {'x_send': [-1, 0],
#  'x_recv': [1, 0],
#  'x_1': [0, 1],
#  'x_2': [0, 0.33],
#  'x_3': [0, -0.33],
#  'x_4': [0, -1]}

# %%
# subax1 = plt.subplot(121)

# pos = nx.spring_layout(G, seed=2)

# options = {
#     'width': 1,
#     'node_color': 'white',
# }


fig = plt.figure(1, figsize=(12, 10), dpi=100)

nx.draw(G,
        pos=pos,
        with_labels=True, 
        font_weight='bold',
        width=1,
        node_color=['lightgray', 'white', 'lightgray', 'white', 'lightgray', 'lightgray'],
        font_family="sans-serif",
        font_size=18,
        clip_on=False,
        # node_shape="8",
        node_size=8000,
)

ax = plt.gca()
ax.collections[0].set_edgecolor("#000000")

# %%
G, s = get_simrank()

# %%
s
# Out:
# defaultdict(list,
#             {'trusted': defaultdict(int,
#                          {'trusted': 1,
#                           'untrusted': 0.2751347479532173,
#                           'semi-trusted': 0.25371670152592224,
#                           '1': 0.400798257652645,
#                           '2': 0.38623426017673235,
#                           '3': 0.3551260469614706,
#                           '4': 0.36945167820602925,
#                           '5': 0.2867666976247857,
#                           '6': 0.36660130304044963,
#                           '7': 0.2792166730961572,
#                           '8': 0.27936018570477256,
#                           '9': 0.2792166730961572,
#                           '10': 0.30706076529479365,
#                           '11': 0.3019424229672764,
#                           '12': 0.2849435910700559,
#                           '13': 0.32037085967010837,
#                           '14': 0.3782987856503371}),
#              'untrusted': defaultdict(int,
#                          {'untrusted': 1,
#                           'trusted': 0.27513474795321724,
#                           'semi-trusted': 0.2737272551885779,
#                           '1': 0.27513474795321724,
#                           '2': 0.30536814142161867,
#                           '3': 0.3414956429530312,
#                           '4': 0.2738225847652492,
#                           '5': 0.33566073103373445,
#                           '6': 0.32310697437968344,
#                           '7': 0.3538287293059969,
#                           '8': 0.2742785511860321,
#                           '9': 0.3538287293059969,
#                           '10': 0.2795893735901064,
#                           '11': 0.3344158031695542,
#                           '12': 0.31782111180037526,
#                           '13': 0.3394106980225758,
#                           '14': 0.2707080314902485}),
#              'semi-trusted': defaultdict(int,
#                          {'semi-trusted': 1,
#                           'trusted': 0.2537167015259223,
#                           'untrusted': 0.2737272551885779,
#                           '1': 0.2537167015259223,
#                           '2': 0.2446462095355745,
#                           '3': 0.25856513700470346,
#                           '4': 0.29643608091861295,
#                           '5': 0.3649825328649804,
#                           '6': 0.24510551030473973,
#                           '7': 0.33678796656635895,
#                           '8': 0.41625130412279765,
#                           '9': 0.33678796656635895,
#                           '8': 0.333737636641537,
#                           '9': 0.3859824035179366,
#                           '11': 0.27874606111329137,
#                           '12': 0.28268771112696456,
#                           '13': 0.2686498435517325,
#                           '14': 0.25845908099407255}),
#              '11': defaultdict(int,
#                          {'11': 1,
#                           'trusted': 0.30194242296727636,
#                           'untrusted': 0.33441580316955427,
#                           'semi-trusted': 0.3431237702084623,
#                           '1': 0.30194242296727636,
#                           '2': 0.2818021955820751,
#                           '3': 0.29098913993268527,
#                           '4': 0.28992485318363487,
#                           '5': 0.3303215537892949,
#                           '6': 0.264999134463242,
#                           '7': 0.33052860712105175,
#                           '8': 0.3516193354210206,
#                           '9': 0.33052860712105175,
#                           '10': 0.27874606111329137,
#                           '12': 0.3758247661228,
#                           '13': 0.35284159442230145,
#                           '14': 0.30603560045383904}),
#              '12': defaultdict(int,
#                          {'12': 1,
#                           'trusted': 0.2849435910700559,
#                           'untrusted': 0.3178211118003752,
#                           'semi-trusted': 0.37198467351054954,
#                           '1': 0.2849435910700559,
#                           '2': 0.2552773889981613,
#                           '3': 0.28782102270209975,
#                           '4': 0.2668518822172941,
#                           '5': 0.34796157376256814,
#                           '6': 0.25109407231034264,
#                           '7': 0.3513583992113998,
#                           '8': 0.3822551034081407,
#                           '9': 0.3513583992113998,
#                           '10': 0.2826877111269646,
#                           '11': 0.3758247661228001,
#                           '13': 0.3740323596360703,
#                           '14': 0.3101639107324157}),
#              '13': defaultdict(int,
#                          {'13': 1,
#                           'trusted': 0.32037085967010837,
#                           'untrusted': 0.3394106980225759,
#                           'semi-trusted': 0.2769974124106312,
#                           '1': 0.32037085967010837,
#                           '2': 0.3154272716764316,
#                           '3': 0.31878553956356154,
#                           '4': 0.3186092009700921,
#                           '5': 0.3128431509076388,
#                           '6': 0.27915575313017305,
#                           '7': 0.32137328862008874,
#                           '8': 0.28032126657463236,
#                           '9': 0.32137328862008874,
#                           '10': 0.2686498435517325,
#                           '11': 0.35284159442230123,
#                           '12': 0.3740323596360703,
#                           '14': 0.3603987020945011}),
#              '14': defaultdict(int,
#                          {'14': 1,
#                           'trusted': 0.3782987856503371,
#                           'untrusted': 0.2707080314902485,
#                           'semi-trusted': 0.24892401535797967,
#                           '1': 0.3782987856503371,
#                           '2': 0.345165551386364,
#                           '3': 0.3317357207640858,
#                           '4': 0.34222622912711675,
#                           '5': 0.2672317109546337,
#                           '6': 0.3551959586201116,
#                           '7': 0.25116833078830897,
#                           '8': 0.2560353899230533,
#                           '9': 0.25116833078830897,
#                           '10': 0.2584590809940726,
#                           '11': 0.306035600453839,
#                           '12': 0.3101639107324157,
#                           '13': 0.36039870209450103})})

# %%
to_draw = dict(s['trusted'].copy())

del to_draw['trusted']
del to_draw['untrusted']
del to_draw['semi-trusted']

to_draw
# Out:
# {'1': 0.400798257652645,
#  '2': 0.38623426017673235,
#  '3': 0.3551260469614706,
#  '4': 0.36945167820602925,
#  '5': 0.2867666976247857,
#  '6': 0.36660130304044963,
#  '7': 0.2792166730961572,
#  '8': 0.27936018570477256,
#  '9': 0.2792166730961572,
#  '10': 0.30706076529479365,
#  '11': 0.3019424229672764,
#  '12': 0.2849435910700559,
#  '13': 0.32037085967010837,
#  '14': 0.3782987856503371}

# %%
thr_1 = 0.35
thr_2 = 0.3

tier_1 = [key for key, value in to_draw.items() if value >= thr_1]
tier_2 = [key for key, value in to_draw.items() if value < thr_1 and value >= thr_2]
tier_3 = [key for key, value in to_draw.items() if value < thr_2]

# %%
tier_3
# Out:
# ['5', '7', '8', '9', '12']

# %%
G_to_draw = G.copy()

# %%
for node in ['trusted', 'untrusted', 'semi-trusted']:
    G_to_draw.remove_node(node)

# %%
colors = ['lightgreen' if i in tier_1 else 'yellow' if i in tier_2 else 'red' for i in  G_to_draw.nodes]

# %%
# subax1 = plt.subplot(121)

pos = nx.spring_layout(G_to_draw, seed=28) #22

# options = {
#     'width': 1,
#     'node_color': 'white',
# }


fig = plt.figure(1, figsize=(12, 10), dpi=250)

nx.draw(G_to_draw,
        pos=pos,
        with_labels=True, 
        font_weight='bold',
        width=1,
        # node_color='lightgray',
        node_color=colors,
        font_family="sans-serif",
        font_size=13,
        clip_on=False,
        # node_shape="8",
        node_size=6*np.array(list(dict(G_to_draw.nodes(data="size", default=100)).values())),
)

ax = plt.gca()
ax.collections[0].set_edgecolor("#000000")

# %%
G, s = get_simrank(node_weights_flag=True)

# %%
s
# Out:
# defaultdict(list,
#             {'trusted': defaultdict(int,
#                          {'trusted': 1,
#                           'untrusted': 0.002783773137522552,
#                           'semi-trusted': 0.0037645411478653148,
#                           '1': 0.034051123335570636,
#                           '2': 0.023041812150212955,
#                           '3': 0.024693208788286,
#                           '4': 0.026112102920918666,
#                           '5': 0.006302111881005624,
#                           '6': 0.024788555036375434,
#                           '7': 0.0060955487180942205,
#                           '8': 0.006564692349282296,
#                           '9': 0.0060955487180942205,
#                           '10': 0.01806297579138908,
#                           '11': 0.009555190381894826,
#                           '12': 0.006959127377023458,
#                           '13': 0.013841554830182352,
#                           '14': 0.036314053372378335}),
#              'untrusted': defaultdict(int,
#                          {'untrusted': 1,
#                           'trusted': 0.002783773137522552,
#                           'semi-trusted': 0.008163917752823805,
#                           '1': 0.003469494324325476,
#                           '2': 0.006864694490982825,
#                           '3': 0.0461904096389349,
#                           '4': 0.003175600692611161,
#                           '5': 0.04317274358004091,
#                           '6': 0.008860697714634483,
#                           '7': 0.05973836326271984,
#                           '8': 0.008031632824792018,
#                           '9': 0.05973836326271984,
#                           '10': 0.01105678504697955,
#                           '11': 0.013140167928177677,
#                           '12': 0.05413027505401837,
#                           '13': 0.08435687455873396,
#                           '14': 0.005389365246184811}),
#              'semi-trusted': defaultdict(int,
#                          {'semi-trusted': 1,
#                           'trusted': 0.003764541147865314,
#                           'untrusted': 0.008163917752823805,
#                           '1': 0.004335781370181035,
#                           '2': 0.00278865084478472,
#                           '3': 0.005591091728902018,
#                           '4': 0.015085044226498779,
#                           '5': 0.0753959203147063,
#                           '6': 0.002372580240514825,
#                           '7': 0.05741778774417028,
#                           '8': 0.0799270175469069,
#                           '5': 0.05284031605701535,
#                           '6': 0.00451554512678201,
#                           '7': 0.12956545063976466,
#                           '8': 0.08058788329434265,
#                           '9': 0.12956545063976466,
#                           '11': 0.011725503983310069,
#                           '12': 0.018368630019626218,
#                           '13': 0.012456806367046588,
#                           '14': 0.005128176140827781}),
#              '11': defaultdict(int,
#                          {'11': 1,
#                           'trusted': 0.009555190381894828,
#                           'untrusted': 0.013140167928177671,
#                           'semi-trusted': 0.04865109616472294,
#                           '1': 0.009895801552672365,
#                           '2': 0.007135279125730617,
#                           '3': 0.007221473338591607,
#                           '4': 0.009883604973089068,
#                           '5': 0.0310684114568877,
#                           '6': 0.0029166567464815924,
#                           '7': 0.015828212627033225,
#                           '8': 0.04305246956298456,
#                           '9': 0.015828212627033225,
#                           '10': 0.011725503983310067,
#                           '12': 0.06908174203488603,
#                           '13': 0.06275035924963687,
#                           '14': 0.051560613981862416}),
#              '12': defaultdict(int,
#                          {'12': 1,
#                           'trusted': 0.006959127377023459,
#                           'untrusted': 0.054130275054018365,
#                           'semi-trusted': 0.06655273675797194,
#                           '1': 0.00737928822097177,
#                           '2': 0.0037685037855220006,
#                           '3': 0.03551909255635977,
#                           '4': 0.00674433986949802,
#                           '5': 0.06501086241080829,
#                           '6': 0.0030353388443705625,
#                           '7': 0.05507662808527001,
#                           '8': 0.058954242491688395,
#                           '9': 0.05507662808527001,
#                           '10': 0.018368630019626218,
#                           '11': 0.06908174203488603,
#                           '13': 0.13218149071939891,
#                           '14': 0.06827943193303217}),
#              '13': defaultdict(int,
#                          {'13': 1,
#                           'trusted': 0.013841554830182354,
#                           'untrusted': 0.08435687455873396,
#                           'semi-trusted': 0.014172005300475216,
#                           '1': 0.014484804558789366,
#                           '2': 0.013600602658988565,
#                           '3': 0.05667899949919391,
#                           '4': 0.015145665074491917,
#                           '5': 0.054171380840479025,
#                           '6': 0.005337613674479986,
#                           '7': 0.07145733142658917,
#                           '8': 0.013605447121428539,
#                           '9': 0.07145733142658917,
#                           '10': 0.012456806367046585,
#                           '11': 0.06275035924963687,
#                           '12': 0.13218149071939891,
#                           '14': 0.10667102070377399}),
#              '14': defaultdict(int,
#                          {'14': 1,
#                           'trusted': 0.036314053372378335,
#                           'untrusted': 0.00538936524618481,
#                           'semi-trusted': 0.008126869601165728,
#                           '1': 0.03686678507678546,
#                           '2': 0.01534394752938589,
#                           '3': 0.027760547291616137,
#                           '4': 0.031656362572949605,
#                           '5': 0.007659405344367257,
#                           '6': 0.036515496505067024,
#                           '7': 0.004705907304569614,
#                           '8': 0.00789700603245384,
#                           '9': 0.004705907304569614,
#                           '10': 0.005128176140827779,
#                           '11': 0.051560613981862416,
#                           '12': 0.06827943193303217,
#                           '13': 0.10667102070377399})})

# %%
to_draw = dict(s['trusted'].copy())

del to_draw['trusted']
del to_draw['untrusted']
del to_draw['semi-trusted']

to_draw
# Out:
# {'1': 0.034051123335570636,
#  '2': 0.023041812150212955,
#  '3': 0.024693208788286,
#  '4': 0.026112102920918666,
#  '5': 0.006302111881005624,
#  '6': 0.024788555036375434,
#  '7': 0.0060955487180942205,
#  '8': 0.006564692349282296,
#  '9': 0.0060955487180942205,
#  '10': 0.01806297579138908,
#  '11': 0.009555190381894826,
#  '12': 0.006959127377023458,
#  '13': 0.013841554830182352,
#  '14': 0.036314053372378335}

# %%
values = list(to_draw.values())

# %%
values
# Out:
# [0.034051123335570636,
#  0.023041812150212955,
#  0.024693208788286,
#  0.026112102920918666,
#  0.006302111881005624,
#  0.024788555036375434,
#  0.0060955487180942205,
#  0.006564692349282296,
#  0.0060955487180942205,
#  0.01806297579138908,
#  0.009555190381894826,
#  0.006959127377023458,
#  0.013841554830182352,
#  0.036314053372378335]

# %%
thr_1 = np.quantile(np.array(values), 0.8)
thr_2 = np.quantile(np.array(values), 0.3)

tier_1 = [key for key, value in to_draw.items() if value >= thr_1]
tier_2 = [key for key, value in to_draw.items() if value < thr_1 and value >= thr_2]
tier_3 = [key for key, value in to_draw.items() if value < thr_2]

# %%
tier_1
# Out:
# ['1', '4', '14']

# %%
tier_2
# Out:
# ['2', '3', '6', '10', '11', '12', '13']

# %%
tier_3
# Out:
# ['5', '7', '8', '9']

# %%
G_to_draw = G.copy()

# %%
for node in ['trusted', 'untrusted', 'semi-trusted']:
    G_to_draw.remove_node(node)

# %%
colors = ['lightgreen' if i in tier_1 else 'yellow' if i in tier_2 else 'red' for i in  G_to_draw.nodes]

# %%
# subax1 = plt.subplot(121)

pos = nx.spring_layout(G_to_draw, seed=28) #22

# options = {
#     'width': 1,
#     'node_color': 'white',
# }


fig = plt.figure(1, figsize=(12, 10), dpi=250)

nx.draw(G_to_draw,
        pos=pos,
        with_labels=True, 
        font_weight='bold',
        width=1,
        # node_color='lightgray',
        node_color=colors,
        font_family="sans-serif",
        font_size=13,
        clip_on=False,
        # node_shape="8",
        node_size=6*np.array(list(dict(G_to_draw.nodes(data="size", default=100)).values())),
)

ax = plt.gca()
ax.collections[0].set_edgecolor("#000000")

# %%
G_untouched = G.copy()

# %%
for node in ['trusted', 'untrusted', 'semi-trusted']:
    G_untouched.remove_node(node)

# %%
# subax1 = plt.subplot(121)

pos = nx.spring_layout(G_untouched, seed=8) #9

# options = {
#     'width': 1,
#     'node_color': 'white',
# }


fig = plt.figure(1, figsize=(12, 10), dpi=400)

nx.draw(G_untouched,
        pos=pos,
        with_labels=True, 
        font_weight='bold',
        width=1,
        #node_color='lightgray',
        font_family="sans-serif",
        font_size=13,
        clip_on=False,
        # node_shape="8",
        node_size=4*np.array(list(dict(G_untouched.nodes(data="size", default=100)).values())),
)

ax = plt.gca()
ax.collections[0].set_edgecolor("#000000")

# edge weight labels
edge_labels = nx.get_edge_attributes(G_untouched, "weight")
nx.draw_networkx_edge_labels(G_untouched, pos, edge_labels, font_size=9, font_family="sans-serif")

ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11768\1611771727.py:36: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
G, s = get_simrank(edges_weights_flag=True)

# %%
for key, value in s['trusted'].items():
    print(f"{key}: {round(value, 3)},")
# Out:
# trusted: 1,
# untrusted: 0.035,
# semi-trusted: 0.031,
# 1: 0.146,
# 2: 0.129,
# 3: 0.109,
# 4: 0.121,
# 5: 0.058,
# 6: 0.117,
# 7: 0.051,
# 8: 0.054,
# 9: 0.051,
# 10: 0.072,
# 11: 0.065,
# 12: 0.055,
# 13: 0.071,
# 14: 0.124,

# %%
s
# Out:
# defaultdict(list,
#             {'trusted': defaultdict(int,
#                          {'trusted': 1,
#                           'untrusted': 0.03525789793181316,
#                           'semi-trusted': 0.0309536669285941,
#                           '1': 0.14564703621536795,
#                           '2': 0.12911586520851265,
#                           '3': 0.10940826655740782,
#                           '4': 0.12059633729758071,
#                           '5': 0.05758690222939652,
#                           '6': 0.11663006095017577,
#                           '7': 0.05106642515570514,
#                           '8': 0.05399952749510997,
#                           '9': 0.05106642515570514,
#                           '10': 0.07187405014448572,
#                           '11': 0.06460777443632668,
#                           '12': 0.05459642596730376,
#                           '13': 0.07073642887530811,
#                           '14': 0.12402821062404468}),
#              'untrusted': defaultdict(int,
#                          {'untrusted': 1,
#                           'trusted': 0.03525789793181316,
#                           'semi-trusted': 0.03077726683068125,
#                           '1': 0.03507896649845048,
#                           '2': 0.06715319580739164,
#                           '3': 0.09835848824800053,
#                           '4': 0.039244287124118496,
#                           '5': 0.0883644779139505,
#                           '6': 0.07987716175325117,
#                           '7': 0.1058413622902569,
#                           '8': 0.02851140608846267,
#                           '9': 0.1058413622902569,
#                           '10': 0.04233865791328543,
#                           '11': 0.08812954868217894,
#                           '12': 0.07193307604629555,
#                           '13': 0.10959110173064994,
#                           '14': 0.03980852477106763}),
#              'semi-trusted': defaultdict(int,
#                          {'semi-trusted': 1,
#                           'trusted': 0.030953666928594095,
#                           'untrusted': 0.030777266830681244,
#                           '1': 0.030908286562773533,
#                           '2': 0.028604593183836832,
#                           '3': 0.031054084702608443,
#                           '4': 0.06694065851044724,
#                           '5': 0.10985853715348895,
#                           '6': 0.029215089391419678,
#                           '7': 0.08027366946204736,
#                           '8': 0.1557334854137933,
#                           '9': 0.08027366946204736,
#                           '10': 0.10541111113855904,
#                           '11': 0.09011603598381404,
#                           '12': 0.11042847380449938,
#                           '13': 0.03560716666798792,
#                           '14': 0.030111056478703022}),
#              '1': defaultdict(int,
#                          {'1': 1,
#                           'trusted': 0.14564703621536793,
#                           'untrusted': 0.03507896649845047,
#                           'semi-trusted': 0.03090828656277354,
#                           '2': 0.132145526068746,
#                           '3': 0.10996865073436779,
#                           '4': 0.1228075347439413,
#                           '5': 0.05754992542868323,
#                           '6': 0.11672232663056903,
#                           '7': 0.05128433162866707,
#                           '8': 0.054228674393670094,
#                           '9': 0.05128433162866707,
#                           '10': 0.07298488484366693,
#                           '11': 0.06625435954027498,
#                           '12': 0.05481735310955539,
#                           '13': 0.074230729162444,
#                           '14': 0.12566694403142914}),
#              '2': defaultdict(int,
#                          {'2': 1,
#                           'trusted': 0.12911586520851262,
#                           'untrusted': 0.06715319580739162,
#                           'semi-trusted': 0.028604593183836832,
#                           'semi-trusted': 0.11042847380449941,
#                           '1': 0.054817353109555406,
#                           '2': 0.03455746451289958,
#                           '3': 0.05742549253326282,
#                           '4': 0.03996310997109953,
#                           '5': 0.09258847024379503,
#                           '6': 0.032658417265974925,
#                           '7': 0.09040841665751069,
#                           '8': 0.12047966430807917,
#                           '9': 0.09040841665751069,
#                           '10': 0.04583125938288304,
#                           '11': 0.1174895269782926,
#                           '13': 0.12250706390241183,
#                           '14': 0.08015787142551739}),
#              '13': defaultdict(int,
#                          {'13': 1,
#                           'trusted': 0.07073642887530811,
#                           'untrusted': 0.10959110173064991,
#                           'semi-trusted': 0.035607166667987925,
#                           '1': 0.074230729162444,
#                           '2': 0.07508544122388704,
#                           '3': 0.07879693805753202,
#                           '4': 0.07762266350729964,
#                           '5': 0.07227108921175482,
#                           '6': 0.04113777591699785,
#                           '7': 0.08275602889842756,
#                           '8': 0.03624313058818925,
#                           '9': 0.08275602889842756,
#                           '10': 0.0306830893812314,
#                           '11': 0.10786625714455124,
#                           '12': 0.12250706390241183,
#                           '14': 0.11247479187905372}),
#              '14': defaultdict(int,
#                          {'14': 1,
#                           'trusted': 0.12402821062404468,
#                           'untrusted': 0.03980852477106763,
#                           'semi-trusted': 0.03011105647870303,
#                           '1': 0.12566694403142914,
#                           '2': 0.09123858602916862,
#                           '3': 0.09437285013332374,
#                           '4': 0.09813600547780847,
#                           '5': 0.045804311861065136,
#                           '6': 0.10581566982028795,
#                           '7': 0.03356178210331475,
#                           '8': 0.03425163457952672,
#                           '9': 0.03356178210331475,
#                           '10': 0.03342318356379659,
#                           '11': 0.07222123966484971,
#                           '12': 0.08015787142551739,
#                           '13': 0.1124747918790537})})

# %%
edges_weights = {(u, v): w for u, v, w in G.edges(data='weight')} | {(v, u): w for u, v, w in G.edges(data='weight')}

# %%
elarge = [(u, v) for (u, v, d) in G.edges(data=True) if u not in ['trusted', 'untrusted', 'semi-trusted']]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if u in ['trusted', 'untrusted', 'semi-trusted']]

pos = nx.spring_layout(G, seed=)  # positions for all nodes - seed for reproducibility

# nodes
nx.draw_networkx_nodes(G, 
                       pos,
                       # font_weight='bold',
                       # width=1,
                       # node_color='lightgray',
                       # font_family="sans-serif",
                       # font_size=13,
                       # clip_on=False,
                       node_size=1.5*np.array(list(dict(G.nodes(data="size", default=100)).values())))

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge, width=1)
nx.draw_networkx_edges(G, pos, edgelist=esmall, width=1, alpha=0.65, style="dashed"
)

# node labels
nx.draw_networkx_labels(G, pos, font_size=12, font_family="sans-serif")
# edge weight labels
edge_labels = nx.get_edge_attributes(G, "weight")
nx.draw_networkx_edge_labels(G, pos, edge_labels, font_size=8, font_family="sans-serif")

ax = plt.gca()
ax.margins(0.08)
plt.axis("off")
plt.tight_layout()
plt.show()

# %%
G, s = get_simrank(weights_flag=True)

# %%
s

# %%
for i, j in G.nodes(data=True):
    print(f"{i}: {j['weight']},")
